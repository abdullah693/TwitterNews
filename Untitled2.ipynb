# %%
import os
os.chdir('D:/Downloads/Twitter_data/twitter_data/twitter_stream/2017/05/01/00')

# %%
os.listdir()
# Out:
# ['1.json',
#  '10.json',
#  '11.json',
#  '12.json',
#  '13.json',
#  '14.json',
#  '15.json',
#  '16.json',
#  '17.json',
#  '18.json',
#  '19.json',
#  '2.json',
#  '20.json',
#  '21.json',
#  '22.json',
#  '23.json',
#  '24.json',
#  '25.json',
#  '26.json',
#  '27.json',
#  '28.json',
#  '29.json',
#  '3.json',
#  '30.json',
#  '30.json.bz2',
#  '31.json',
#  '31.json.bz2',
#  '32.json.bz2',
#  '33.json.bz2',
#  '34.json.bz2',
#  '35.json.bz2',
#  '36.json.bz2',
#  '37.json.bz2',
#  '38.json.bz2',
#  '39.json.bz2',
#  '4.json',
#  '40.json.bz2',
#  '41.json.bz2',
#  '42.json.bz2',
#  '43.json.bz2',
#  '44.json.bz2',
#  '45.json.bz2',
#  '46.json.bz2',
#  '47.json.bz2',
#  '48.json.bz2',
#  '49.json.bz2',
#  '5.json',
#  '50.json.bz2',
#  '51.json.bz2',
#  '52.json.bz2',
#  '53.json.bz2',
#  '54.json.bz2',
#  '55.json.bz2',
#  '56.json.bz2',
#  '57.json.bz2',
#  '58.json.bz2',
#  '59.json.bz2',
#  '6.json',
#  '7.json',
#  '8.json',
#  '9.json']

# %%
import ijson

filename = "2.json"
with open(filename, 'r') as f:
    objects = ijson.items(f, 'data.item')

# %%
objects
# Out:
# <generator object items at 0x0000026BC2015D58>

# %%
import json
import csv
import io
data_json = open('2.json', 'r', encoding='utf-8')

# %%
import langid
import pandas as pd

# %%
tweets_csv = pd.DataFrame()

# %%
ctr = 0
error_count = 0
ctr_useful = 0
with open('2.json', 'r') as infile:
    for line in infile:
        tweet = json.loads(line)
        ctr += 1
        try:
            if tweet['text'] != None:
                if ((langid.classify(tweet['text'])[0] == 'en') | (langid.classify(tweet['text'])[0] == 'ur')):
                    tweet = nlp(tweet)
                    if 'RT' not in w.text and w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and not w.like_url:
                        
  
                    ctr_useful += 1
                    print(tweet['text'])
        except:
            error_count += 1
            print(tweet)
print(ctr)
# Out:
# Hahahahahahahahahahaha
# RT @stephanyregan_: They even have a cute painting party!!!! https://t.co/R9MZdmWPZr
# RT @SkizzyMars: i want u to myself.  i'm greedy
# RT @TypicalMsian: What's better than public holiday on Monday?
#
# Two weeks in a row of public holiday on Monday. https://t.co/jOkY6Q49Qg
# RT @BTS_twt: Finally!! brother @Wale 's new album
#
# #SHINE 🌙🌙 https://t.co/V9IHUtZbxk
# Ready for this weekend
# chill movie night with my baby 😍
# RT @miguel_kraig: Live without pretending, Love without depending, Listen without defending, Speak without offending.
#
# #KissesADecadeAnd8
# @…
# RT @kyungsoo_stan: EXO-CBX Japanese Album "Girls" is sold out! https://t.co/vchZ2PhUm7
# Treat yourself to a bank holiday brunch!  https://t.co/8cUQGPOyFg
# I'm Live My Doods! https://t.co/qXWC2Bps1z
# RT @qz: Here are the five universal laws of stupidity https://t.co/C2v65N3NcO
# RT @UduakAmimo: “A dream doesn’t become reality through magic; it takes sweat, determination and hard work.”
#
# ...

# %%
print(ctr_useful)
# Out:
# 605

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens
 
tweet = 'RT @marcobonzanini: just an example! :D http://example.com #NLP'
print(' '.join(preprocess(tweet)))
# ['RT', '@marcobonzanini', ':', 'just', 'an', 'example', '!', ':D', 'http://example.com', '#NLP']
# Out:
# RT @marcobonzanini : just an example ! :D http://example.com #NLP

# %%
import spacy

# %%
nlp = spacy.load('xx')

# %%
tweet = nlp('RT @blxcknicotine: Winner "Really Really" dance practice video is so 😍👌🏽 https://t.co/q7LpTg14iI \n')

# %%
texts, article = [], []
for w in tweet:
        # if it's not a stop word or punctuation mark, add it to our article!
    if 'RT' not in w.text and w.text != '\n' and not w.is_stop and not w.is_punct and not w.like_num and not w.like_url:
        # we add the lematized version of the word
        article.append(w.lemma_.lower())
        # if it's a new line, it means we're onto our next document
    if w.text == '\n':
        texts.append(article)
        article = []

# %%
texts
# Out:
# [['@blxcknicotine',
#   'winner',
#   'really',
#   'really',
#   'dance',
#   'practice',
#   'video',
#   '😍',
#   '👌',
#   '🏽']]

# %%
w.lower_
# Out:
# '\n'
